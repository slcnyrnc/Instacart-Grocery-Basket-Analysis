# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/selcenayranci/Desktop/4th Achievement -  Instacart Basket Analysis March 2024'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02. Data', 'Prepared Data', 'orders_products_merged_new.pkl'))

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     0.0         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered _merge product_name  aisle_id  department_id  prices  \
# ...

# %%
# Creating a subset called df of the first one million entries

df = ords_prods_merge[:1000000]

# %%
# Check the shape of the new df

df.shape
# Out:
# (1000000, 20)

# %%
df.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     0.0         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered _merge product_name  aisle_id  department_id  prices  \
# ...

# %%
# Splitting the data into groups

df.groupby('product_name')

# %%
# Split the data into groups based on “department_id” and aggregating to mean for “order_number” 

df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
# Performing Multiple Aggregations

df.groupby('department_id').agg({'order_number': ['mean', 'max', 'min']})
# Out:
#               order_number
#                       mean max min
# department_id
# 4                18.825780  99   1
# 7                17.472355  99   1
# 13               17.993423  99   1
# 14               19.246334  99   1
# 16               19.463012  99   1
# 17               11.294069  98   1
# 19               19.305237  99   1
# 20               17.599636  99   1

# %%
# Aggregating Data with transform()

ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# /var/folders/2x/0t2m4vy54v5c0rw53p6_5xv00000gn/T/ipykernel_46310/2985312573.py:3: FutureWarning: The provided callable <function max at 0x109113b00> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(20)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2398795        1    prior             2                   3
# 2     473747        1    prior             3                   3
# 3    2254736        1    prior             4                   4
# 4     431534        1    prior             5                   4
# 5    3367565        1    prior             6                   2
# 6     550135        1    prior             7                   1
# 7    3108588        1    prior             8                   1
# 8    2295261        1    prior             9                   1
# 9    2550362        1    prior            10                   4
# 10   2968173       15    prior            15                   1
# 11   1870022       15    prior            17                   2
# 12   1911383       15    prior            18                   2
# ...

# %%
# Deriving Columns with loc()

ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15891077
# Loyal customer      10293737
# New customer         6249398
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# ...

# %% [markdown]
# ## Task - 4.8 Grouping Data and Aggregating Variables

# %% [markdown]
# ### Question 2

# %% [markdown]
# ### Question 3

# %% [markdown]
# ### Question 5

# %%
ords_prods_merge.groupby('loyalty_flag')['prices'].mean()
# Out:
# loyalty_flag
# Loyal customer      10.388747
# New customer        13.294370
# Regular customer    12.496203
# Name: prices, dtype: float64

# %%
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'max', 'min']})
# Out:
#                      prices
#                        mean      max  min
# loyalty_flag
# Loyal customer    10.388747  99999.0  1.0
# New customer      13.294370  99999.0  1.0
# Regular customer  12.496203  99999.0  1.0

# %%
# It looks like loyal customers usually to spend less on average compared to new or regular customers

# %% [markdown]
# ### Question 6

# %%
# Split data into groups based on “user_id” and aggregating to mean for “prices” 

ords_prods_merge.groupby('user_id').agg({'prices': ['mean']})
# Out:
#            prices
#              mean
# user_id
# 1        6.367797
# 2        7.515897
# 3        8.197727
# 4        8.205556
# 5        9.189189
# ...           ...
# 206205   8.909375
# 206206   7.646667
# 206207   7.313453
# 206208   8.366617
# 206209   7.058915
#
# [206209 rows x 1 columns]

# %%
# Aggregating Data with transform()

ords_prods_merge['avg_spending'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# /var/folders/2x/0t2m4vy54v5c0rw53p6_5xv00000gn/T/ipykernel_46310/3804257368.py:3: FutureWarning: The provided callable <function mean at 0x109120540> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['avg_spending'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     0.0         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered  ... prices    price_range_loc     busiest day  \
# ...

# %%
#  Creating a spending flag

ords_prods_merge.loc[ords_prods_merge['avg_spending'] < 10, 'spending_flag'] = 'Low spender'
ords_prods_merge.loc[ords_prods_merge['avg_spending'] >= 10, 'spending_flag'] = 'High spender'

# %%
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     31798751
# High spender      635461
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'avg_spending', 'spending_flag']].head (100)
# Out:
#     user_id  avg_spending spending_flag
# 0         1      6.367797   Low spender
# 1         1      6.367797   Low spender
# 2         1      6.367797   Low spender
# 3         1      6.367797   Low spender
# 4         1      6.367797   Low spender
# ..      ...           ...           ...
# 95      360     10.006250  High spender
# 96      377      8.496552   Low spender
# 97      387      7.396610   Low spender
# 98      420      7.657813   Low spender
# 99      420      7.657813   Low spender
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Question 7

# %%
# Split data into groups based on “user_id” and aggregating to median for “days_since_prior_order” 

ords_prods_merge.groupby('user_id').agg({'days_since_prior_order': ['median']})
# Out:
#         days_since_prior_order
#                         median
# user_id
# 1                         20.0
# 2                         13.0
# 3                          9.0
# 4                         17.0
# 5                         11.0
# ...                        ...
# 206205                     0.0
# 206206                     3.0
# 206207                     8.0
# 206208                     7.0
# 206209                    18.0
#
# [206209 rows x 1 columns]

# %%
# Aggregating Data with transform()

ords_prods_merge['order_frequency'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
# Out:
# /var/folders/2x/0t2m4vy54v5c0rw53p6_5xv00000gn/T/ipykernel_46310/2146164887.py:3: FutureWarning: The provided callable <function median at 0x1092605e0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   ords_prods_merge['order_frequency'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     0.0         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered  ...    price_range_loc     busiest day  busiest_period_of_day  \
# ...

# %%
#  Creating an order frequency flag

ords_prods_merge.loc[ords_prods_merge['order_frequency'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'
ords_prods_merge.loc[(ords_prods_merge['order_frequency'] <= 20) & (ords_prods_merge['order_frequency'] > 10), 'order_frequency_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['order_frequency'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# order_frequency_flag
# Frequent customer        22814871
# Regular customer          6929354
# Non-frequent customer     2689987
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'order_frequency', 'order_frequency_flag']].head (50)
# Out:
#     user_id  order_frequency order_frequency_flag
# 0         1             20.0     Regular customer
# 1         1             20.0     Regular customer
# 2         1             20.0     Regular customer
# 3         1             20.0     Regular customer
# 4         1             20.0     Regular customer
# 5         1             20.0     Regular customer
# 6         1             20.0     Regular customer
# 7         1             20.0     Regular customer
# 8         1             20.0     Regular customer
# 9         1             20.0     Regular customer
# 10       15              8.0    Frequent customer
# 11       15              8.0    Frequent customer
# 12       15              8.0    Frequent customer
# 13       15              8.0    Frequent customer
# 14       15              8.0    Frequent customer
# 15       19              6.0    Frequent customer
# 16       19              6.0    Frequent customer
# 17       19              6.0    Frequent customer
# ...

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02. Data', 'Prepared Data', 'ords_prods_merge_aggregate.pkl'))
